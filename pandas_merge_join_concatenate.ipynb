# %%
import pandas as pd
import numpy as np

# %%
nov_reg = pd.read_csv("reg-month1.csv")
dec_reg = pd.read_csv("reg-month2.csv")
matches = pd.read_csv("matches.csv")
courses =pd.read_csv("courses.csv")
course_xl = pd.read_excel("courses.xlsx")
reg_month2_xl = pd.read_excel("reg-month2.xlsx")
student = pd.read_csv("students.csv")
student_xl = pd.read_excel("students.xlsx") 
delivery = pd.read_csv("deliveries.csv")

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
course_xl
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
student
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
nov_reg
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
matches
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
delivery
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %% [markdown]
# ### Concat

# %%
pd.concat([nov_reg,dec_reg],ignore_index=True)
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
multi = pd.concat([nov_reg,dec_reg],keys=["Nov","Dec"])
# Multi index dataframe
multi
# Out:
#         student_id  course_id
# Nov 0           23          1
#     1           15          5
#     2           18          6
#     3           23          4
#     4           16          9
#     5           18          1
#     6            1          1
#     7            7          8
#     8           22          3
#     9           15          1
#     10          19          4
#     11           1          6
#     12           7         10
#     13          11          7
#     14          13          3
#     15          24          4
#     16          21          1
#     17          16          5
#     18          23          3
#     19          17          7
#     20          23          6
#     21          25          1
#     22          19          2
#     23          25         10
#     24           3          3
# Dec 0            3          5
#     1           16          7
#     2           12         10
#     3           12          1
#     4           14          9
# ...

# %%
multi.loc[("Dec",4)]
# Out:
# student_id    14
# course_id      9
# Name: (Dec, 4), dtype: int64

# %%
pd.concat([nov_reg,dec_reg],axis=1)
# Out:
#     student_id  course_id  student_id  course_id
# 0         23.0        1.0           3          5
# 1         15.0        5.0          16          7
# 2         18.0        6.0          12         10
# 3         23.0        4.0          12          1
# 4         16.0        9.0          14          9
# 5         18.0        1.0           7          7
# 6          1.0        1.0           7          2
# 7          7.0        8.0          16          3
# 8         22.0        3.0          17         10
# 9         15.0        1.0          11          8
# 10        19.0        4.0          14          6
# 11         1.0        6.0          12          5
# 12         7.0       10.0          12          7
# 13        11.0        7.0          18          8
# 14        13.0        3.0           1         10
# 15        24.0        4.0           1          9
# 16        21.0        1.0           2          5
# 17        16.0        5.0           7          6
# ...

# %% [markdown]
# ### Joins

# %%
student.merge(dec_reg,how="inner",on="student_id")
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23         10
# 1            1       Kailash Harjo       23          9
# 2            2         Esha Butala        1          5
# 3            3      Parveen Bhalla        3          5
# 4            7        Tarun Thaker        9          7
# 5            7        Tarun Thaker        9          2
# 6            7        Tarun Thaker        9          6
# 7           11  David Mukhopadhyay       20          8
# 8           11  David Mukhopadhyay       20         10
# 9           12          Radha Dutt       19         10
# 10          12          Radha Dutt       19          1
# 11          12          Radha Dutt       19          5
# 12          12          Radha Dutt       19          7
# 13          14    Pranab Natarajan       22          9
# 14          14    Pranab Natarajan       22          6
# 15          14    Pranab Natarajan       22          4
# ...

# %%
courses.merge(nov_reg,how="left",on="course_id")
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499        23.0
# 1           1            python   2499        18.0
# 2           1            python   2499         1.0
# 3           1            python   2499        15.0
# 4           1            python   2499        21.0
# 5           1            python   2499        25.0
# 6           2               sql   3499        19.0
# 7           3     data analysis   4999        22.0
# 8           3     data analysis   4999        13.0
# 9           3     data analysis   4999        23.0
# 10          3     data analysis   4999         3.0
# 11          4  machine learning   9999        23.0
# 12          4  machine learning   9999        19.0
# 13          4  machine learning   9999        24.0
# 14          5           tableau   2499        15.0
# 15          5           tableau   2499        16.0
# 16          6          power bi   1899        18.0
# ...

# %%
nov_reg.merge(student,how="right",on="student_id")
# Out:
#     student_id  course_id                name  partner
# 0            1        1.0       Kailash Harjo       23
# 1            1        6.0       Kailash Harjo       23
# 2            2        NaN         Esha Butala        1
# 3            3        3.0      Parveen Bhalla        3
# 4            4        NaN         Marlo Dugal       14
# 5            5        NaN         Kusum Bahri        6
# 6            6        NaN  Lakshmi Contractor       10
# 7            7        8.0        Tarun Thaker        9
# 8            7       10.0        Tarun Thaker        9
# 9            8        NaN      Radheshyam Dey        5
# 10           9        NaN   Nitika Chatterjee        4
# 11          10        NaN      Aayushman Sant        8
# 12          11        7.0  David Mukhopadhyay       20
# 13          12        NaN          Radha Dutt       19
# 14          13        3.0      Munni Varghese       24
# 15          14        NaN    Pranab Natarajan       22
# ...
